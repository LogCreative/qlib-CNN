# %%
# !python get_data.py qlib_data --target_dir H:/qlib-CNN/data/cn_data --region cn
# Out:
# 2021-12-13 22:06:05.064 | WARNING  | qlib.tests.data:_download_data:54 - The data for the example is collected from Yahoo Finance. Please be aware that the quality of the data might not be perfect. (You can refer to the original data source: https://finance.yahoo.com/lookup.)
# 2021-12-13 22:06:05.064 | INFO     | qlib.tests.data:_download_data:57 - qlib_data_cn_1d_latest.zip downloading......
#
# ...
# 100%|█████████▉| 216633344/216676710 [00:38<00:00, 6362346.04it/s]
# 216677376it [00:38, 5637210.76it/s]
# 2021-12-13 22:06:43.506 | WARNING  | qlib.tests.data:_unzip:79 - will delete the old qlib data directory(features, instruments, calendars, features_cache, dataset_cache): H:\qlib-CNN\data\cn_data
# 2021-12-13 22:06:43.507 | INFO     | qlib.tests.data:_unzip:83 - H:\qlib-CNN\data\cn_data\20211213220604_qlib_data_cn_1d_latest.zip unzipping......
#
# ...
# 100%|██████████| 43788/43788 [00:56<00:00, 770.31it/s]

# %%
import qlib
from qlib.data import D
qlib.init(provider_uri='H:/qlib-CNN/data/cn_data')
instruments = D.instruments(market='csi300')
D.list_instruments(instruments=instruments, start_time='2010-01-01', end_time='2017-12-31', as_list=True)[:20]
# Out:
# [15060:MainThread](2021-12-13 22:15:03,114) INFO - qlib.Initialization - [config.py:386] - default_conf: client.
# [15060:MainThread](2021-12-13 22:15:05,118) WARNING - qlib.Initialization - [config.py:411] - redis connection failed(host=127.0.0.1 port=6379), DiskExpressionCache and DiskDatasetCache will not be used!
# [15060:MainThread](2021-12-13 22:15:05,570) INFO - qlib.Initialization - [__init__.py:56] - qlib successfully initialized based on client settings.
# [15060:MainThread](2021-12-13 22:15:05,571) INFO - qlib.Initialization - [__init__.py:58] - data_path={'__DEFAULT_FREQ': WindowsPath('H:/qlib-CNN/data/cn_data')}
# ['SH600000',
#  'SH600009',
#  'SH600010',
#  'SH600011',
#  'SH600015',
#  'SH600016',
#  'SH600018',
#  'SH600019',
#  'SH600028',
#  'SH600029',
#  'SH600030',
#  'SH600031',
#  'SH600036',
#  'SH600048',
#  'SH600050',
#  'SH600061',
#  'SH600079',
#  'SH600085',
#  'SH600104',
#  'SH600109']
